# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/KidWeight.csv")

# %%
plt.xlabel("Person Number")
plt.ylabel("Weight")
plt.grid()
plt.scatter(df["Person Number"],df["Weight"],color='red',marker='+')
plt.plot(df["Person Number"],df["Weight"])
